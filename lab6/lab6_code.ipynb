# %% [markdown]
# # NOUN/ VERB

# %%
# pip install spacy
# python -m spacy download en_core_web_sm

import spacy

# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load("en_core_web_sm")

# Process whole documents
text = ("When Sebastian Thrun started working on self-driving cars at "
        "Google in 2007, few people outside of the company took him "
        "seriously. “I can tell you very senior CEOs of major American "
        "car companies would shake my hand and turn away because I wasn’t "
        "worth talking to,” said Thrun, in an interview with Recode earlier "
        "this week.")
doc = nlp(text)

# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)

# %%
lis = ['span', 'enjoy', 'cancel', 'make', 'can', 'accord', 'come', 'pay', 'own', 'add', 'remain', 'buy', 'pertain', 'prefer', 'order', 'facilitate', 'type', 'follow', 'recur', 'meet', 'keep', 'happen', 'resolve', 'debit', 'approve', 'notify', 'presuppose', 'exist', 'desire', 'fetch', 'scale', 'perform', 'query', 'understand', 'recommend', 'deliver', 'require', 'maintain', 'incorporate', 'shall', 'view', 'transfer', 'regard', 'login', 'wish', 'aim', 'register', 'create', 'need', 'have', 'improve', 'redirect', 'enable', 'use', 'access', 'update', 'issue', 'contain', 'sell', 'possess', 'ensure', 'sustain', 'cater', 'modify', 'validate', '’', 'block', 'suspend', 'prompt', 'may', 'assume', 'initiate', 'operate', 'read', 'should', 'credit', 'display', 'deduct', 'go', 'include', 'shop', 'report', 'help', 'search', 'give', 'log', 'look', 'save', 'handle', 'would', 'check', 'dedicate', 'will', 'set', 'allow', 'store', 'could', 'decide', 'gain', 'provide']

# %%
len(lis)
# Out:
# 100

# %%
import numpy as np
import pandas as pd

# %%
num = np.array(lis)
reshaped = num.reshape(20,5)
df = pd.DataFrame(reshaped, columns=['Verb','Verb','Verb','Verb','Verb'])
df
# Out:
#           Verb        Verb      Verb         Verb       Verb
# 0         span       enjoy    cancel         make        can
# 1       accord        come       pay          own        add
# 2       remain         buy   pertain       prefer      order
# 3   facilitate        type    follow        recur       meet
# 4         keep      happen   resolve        debit    approve
# 5       notify  presuppose     exist       desire      fetch
# 6        scale     perform     query   understand  recommend
# 7      deliver     require  maintain  incorporate      shall
# 8         view    transfer    regard        login       wish
# 9          aim    register    create         need       have
# 10     improve    redirect    enable          use     access
# 11      update       issue   contain         sell    possess
# 12      ensure     sustain     cater       modify   validate
# 13           ’       block   suspend       prompt        may
# ...

# %%
df.to_csv('verb1.csv')
